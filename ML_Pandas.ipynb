# %% [markdown]
# <a href="https://colab.research.google.com/github/syedareehaquasar/ML-Practice/blob/main/ML_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !head 01_heights_weights_genders.csv
# Out:
# "Gender","Height","Weight"
# "Male",73.847017017515,241.893563180437
# "Male",68.7819040458903,162.310472521300
# "Male",74.1101053917849,212.7408555565
# "Male",71.7309784033377,220.042470303077
# "Male",69.8817958611153,206.349800623871
# "Male",67.2530156878065,152.212155757083
# "Male",68.7850812516616,183.927888604031
# "Male",68.3485155115879,167.971110489509
# "Male",67.018949662883,175.92944039571

# %%
DATA = "01_heights_weights_genders.csv"

# %%
# !tail 01_heights_weights_genders.csv
# Out:
# "Female",63.1794982498071,141.266099582434
# "Female",62.6366749337994,102.853563214830
# "Female",62.0778316936514,138.691680275738
# "Female",60.0304337715611,97.6874322554917
# "Female",59.0982500313486,110.529685683049
# "Female",66.1726521477708,136.777454183235
# "Female",67.067154649054,170.867905890713
# "Female",63.8679922137577,128.475318784122
# "Female",69.0342431307346,163.852461346571
# "Female",61.9442458795172,113.649102675312

# %%
# !head -n 7 01_heights_weights_genders.csv
# Out:
# "Gender","Height","Weight"
# "Male",73.847017017515,241.893563180437
# "Male",68.7819040458903,162.310472521300
# "Male",74.1101053917849,212.7408555565
# "Male",71.7309784033377,220.042470303077
# "Male",69.8817958611153,206.349800623871
# "Male",67.2530156878065,152.212155757083

# %%
FIRST_LINE = True
data = []
for line in open(DATA):
  if FIRST_LINE:
    FIRST_LINE = False
  else:
    data.append(line.strip())

# %%
len(data)
# Out:
# 10000

# %%
len(DATA)
# Out:
# 30

# %%
FIRST_LINE = True
COMMA, QUOTE = ",", '"'
data = []
for line in open(DATA):
  if FIRST_LINE:
    FIRST_LINE = False
  else:
    g, h, w = line.strip().split(COMMA)
    data.append([g.strip(QUOTE), float(h), float(w)])

# %%
data[:10]
# Out:
# [['Male', 73.847017017515, 241.893563180437],
#  ['Male', 68.7819040458903, 162.3104725213],
#  ['Male', 74.1101053917849, 212.7408555565],
#  ['Male', 71.7309784033377, 220.042470303077],
#  ['Male', 69.8817958611153, 206.349800623871],
#  ['Male', 67.2530156878065, 152.212155757083],
#  ['Male', 68.7850812516616, 183.927888604031],
#  ['Male', 68.3485155115879, 167.971110489509],
#  ['Male', 67.018949662883, 175.92944039571],
#  ['Male', 63.4564939783664, 156.399676387112]]

# %%
data
# Out:
# [['Male', 73.847017017515, 241.893563180437],
#  ['Male', 68.7819040458903, 162.3104725213],
#  ['Male', 74.1101053917849, 212.7408555565],
#  ['Male', 71.7309784033377, 220.042470303077],
#  ['Male', 69.8817958611153, 206.349800623871],
#  ['Male', 67.2530156878065, 152.212155757083],
#  ['Male', 68.7850812516616, 183.927888604031],
#  ['Male', 68.3485155115879, 167.971110489509],
#  ['Male', 67.018949662883, 175.92944039571],
#  ['Male', 63.4564939783664, 156.399676387112],
#  ['Male', 71.1953822829745, 186.604925560358],
#  ['Male', 71.6408051192206, 213.741169489411],
#  ['Male', 64.7663291334055, 167.127461073476],
#  ['Male', 69.2830700967204, 189.446181386738],
#  ['Male', 69.2437322298112, 186.434168021239],
#  ['Male', 67.6456197004212, 172.186930058117],
#  ['Male', 72.4183166259878, 196.028506330482],
#  ['Male', 63.974325721061, 172.88347020878],
#  ['Male', 69.6400598997523, 185.98395757313],
#  ['Male', 67.9360048540095, 182.426648013226],
# ...

# %%
POUNDS2KG, INCHES2CM = 0.454, 2.54
FIRST_LINE = True
COMMA, QUOTE = ",", '"'
data = []
for line in open(DATA):
  if FIRST_LINE:
    FIRST_LINE = False
  else:
    g_raw, h_raw, w_raw = line.strip().split(COMMA)
    g = g_raw.strip(QUOTE)
    h = int(float(h_raw) * INCHES2CM + 0.5)
    w = int(float(w_raw) * POUNDS2KG + 0.5)
    data.append([g, h, w])

# %%
data[:10]
# Out:
# [['Male', 188, 110],
#  ['Male', 175, 74],
#  ['Male', 188, 97],
#  ['Male', 182, 100],
#  ['Male', 177, 94],
#  ['Male', 171, 69],
#  ['Male', 175, 84],
#  ['Male', 174, 76],
#  ['Male', 170, 80],
#  ['Male', 161, 71]]

# %%
sum([h for g, h, w in data])/len(data)
# Out:
# 168.5691

# %%
import pandas as pd

# %%
pd.read_csv(DATA)
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
data = pd.read_csv(DATA)

# %%
data.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
data.Height
# Out:
# 0       73.847017
# 1       68.781904
# 2       74.110105
# 3       71.730978
# 4       69.881796
#           ...
# 9995    66.172652
# 9996    67.067155
# 9997    63.867992
# 9998    69.034243
# 9999    61.944246
# Name: Height, Length: 10000, dtype: float64

# %%
data.Weight
# Out:
# 0       241.893563
# 1       162.310473
# 2       212.740856
# 3       220.042470
# 4       206.349801
#            ...
# 9995    136.777454
# 9996    170.867906
# 9997    128.475319
# 9998    163.852461
# 9999    113.649103
# Name: Weight, Length: 10000, dtype: float64

# %%
data.Gender
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 9995    Female
# 9996    Female
# 9997    Female
# 9998    Female
# 9999    Female
# Name: Gender, Length: 10000, dtype: object

# %%
data["Gender"]
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 9995    Female
# 9996    Female
# 9997    Female
# 9998    Female
# 9999    Female
# Name: Gender, Length: 10000, dtype: object

# %%
trial = pd.read_csv("trial.txt")

# %%
trial.0
# Out:
#   File "<ipython-input-43-b2127e93f839>", line 1
#     trial.0
#           ^
# SyntaxError: invalid syntax

# %%
trial[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-5848db96b717> in <module>()
# ----> 1 trial[0]
#
# ...

# %%
trial
# Out:
#     reeha   65   20
# 0  Asokan   20   23
# 1   apple   11   20

# %%
trial = pd.read_csv("trial.txt", header=None)

# %%
trial
# Out:
#         0   1   2
# 0   reeha  65  20
# 1  Asokan  20  23
# 2   apple  11  20

# %%
trial.0
# Out:
#   File "<ipython-input-50-b2127e93f839>", line 1
#     trial.0
#           ^
# SyntaxError: invalid syntax

# %%
trial[0]
# Out:
# 0     reeha
# 1    Asokan
# 2     apple
# Name: 0, dtype: object

# %%
trial1 = pd.read_csv("trial.txt", header=0, names=["Name of Student", "Age", "weight"])

# %%
trial1
# Out:
#   Name of Student  Age  weight
# 0          Asokan   20      23
# 1           apple   11      20

# %%
trial1['Name of Student']
# Out:
# 0    Asokan
# 1     apple
# Name: Name of Student, dtype: object

# %%
trial1."Name of Student"
# Out:
#   File "<ipython-input-57-aeab9f291a98>", line 1
#     trial1."Name of Student"
#                            ^
# SyntaxError: invalid syntax

# %%
def pounds2kg(s: str) -> int:
  return int(float(s) * POUNDS2KG + 0.5)

def inches2cm(s: str) -> int:
  return int(float(s) * INCHES2CM + 0.5)

# %%
data = pd.read_csv(DATA, converters={'Height': inches2cm, 'Weight':pounds2kg})

# %%
data
# Out:
#       Gender  Height  Weight
# 0       Male     188     110
# 1       Male     175      74
# 2       Male     188      97
# 3       Male     182     100
# 4       Male     177      94
# ...      ...     ...     ...
# 9995  Female     168      62
# 9996  Female     170      78
# 9997  Female     162      58
# 9998  Female     175      74
# 9999  Female     157      52
#
# [10000 rows x 3 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head
# Out:
# <bound method NDFrame.head of       Gender  Height  Weight
# 0       Male     188     110
# 1       Male     175      74
# 2       Male     188      97
# 3       Male     182     100
# 4       Male     177      94
# ...      ...     ...     ...
# 9995  Female     168      62
# 9996  Female     170      78
# 9997  Female     162      58
# 9998  Female     175      74
# 9999  Female     157      52
#
# [10000 rows x 3 columns]>

# %%
data.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean     168.569100     73.294000
# std        9.781605     14.573867
# min      138.000000     29.000000
# 25%      161.000000     62.000000
# 50%      168.000000     73.000000
# 75%      176.000000     85.000000
# max      201.000000    123.000000

# %%
data.memory_usage(deep=True)
# Out:
# Index        128
# Gender    620000
# Height     80000
# Weight     80000
# dtype: int64

# %%
data.memory_usage()
# Out:
# Index       128
# Gender    80000
# Height    80000
# Weight    80000
# dtype: int64

# %%
tall = data[data.Height >= 180]

# %%
tall.describe()
# Out:
#             Height       Weight
# count  1455.000000  1455.000000
# mean    183.891409    93.872165
# std       3.612111     6.121209
# min     180.000000    73.000000
# 25%     181.000000    90.000000
# 50%     183.000000    93.000000
# 75%     186.000000    98.000000
# max     201.000000   123.000000

# %%
pd.read_csv?

# %%
men = data[data.Gender == "Male"]

# %%
women = data[data.Gender == "Female"]

# %%
men.describe()
# Out:
#             Height       Weight
# count  5000.000000  5000.000000
# mean    175.327000    84.901200
# std       7.286748     8.982181
# min     148.000000    51.000000
# 25%     171.000000    79.000000
# 50%     175.000000    85.000000
# 75%     180.000000    91.000000
# max     201.000000   123.000000

# %%
women.describe()
# Out:
#             Height       Weight
# count  5000.000000  5000.000000
# mean    161.811200    61.686800
# std       6.850207     8.640025
# min     138.000000    29.000000
# 25%     157.000000    56.000000
# 50%     162.000000    62.000000
# 75%     167.000000    68.000000
# max     186.000000    92.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(men.Height, men.Weight, "r.")

# %%
plt.plot(men.Height, men.Weight, "r.")
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
plt.plot(women.Height, women.Weight, "g+")

# %%
plt.plot(men.Height, men.Weight)
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
plt.plot(women.Height, women.Weight)

# %%
plt.plot(men.Height, men.Weight, "k*")
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
# Out:
# Text(0, 0.5, 'Weight (kg)')

# %%
plt.plot?

# %%
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, title, sort_colors=True, emptycols=0):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12
    topmargin = 40

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in colors.items())
        names = [name for hsv, name in by_hsv]
    else:
        names = list(colors)

    n = len(names)
    ncols = 4 - emptycols
    nrows = n // ncols + int(n % ncols > 0)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + margin + topmargin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-topmargin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()
    ax.set_title(title, fontsize=24, loc="left", pad=10)

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

plot_colortable(mcolors.BASE_COLORS, "Base Colors",
                sort_colors=False, emptycols=1)
plot_colortable(mcolors.TABLEAU_COLORS, "Tableau Palette",
                sort_colors=False, emptycols=2)

plot_colortable(mcolors.CSS4_COLORS, "CSS Colors")

# Optionally plot the XKCD colors (Caution: will produce large figure)
#xkcd_fig = plot_colortable(mcolors.XKCD_COLORS, "XKCD Colors")
#xkcd_fig.savefig("XKCD_Colors.png")

plt.show()
